# %% [markdown]
# ## Goal
#
# ## Categorization
# [Execution/PowerShell](https://attack.mitre.org/techniques/T1086)
#
# ## Strategy Abstract
#
# ## Technical Context
#
# ## Blind Spots and Assumptions
#
# ## False Positives
#
# ## Priority
#
# ## Validation
#
# ## Response
#
# ## Additional Resources
#
#  - [TechNet PowerShell](https://technet.microsoft.com/en-us/scriptcenter/dd742419.aspx)
#
#  - [Powersploit](https://github.com/mattifestation/PowerSploit)
#
#  - [Github PSAttack](https://github.com/jaredhaight/PSAttack)
#
#  - [Sixdub PowerPick Jan 2016](http://www.sixdub.net/?p=367)
#
#  - [SilentBreak Offensive PS Dec 2015](https://silentbreaksecurity.com/powershell-jobs-without-powershell-exe/)
#
#  - [Microsoft PSfromCsharp APR 2014](https://blogs.msdn.microsoft.com/kebab/2014/04/28/executing-powershell-scripts-from-c/)
#
#  - [Malware Archaeology PowerShell Cheat Sheet](http://www.malwarearchaeology.com/s/Windows-PowerShell-Logging-Cheat-Sheet-ver-June-2016-v2.pdf)
#
#  - [FireEye PowerShell Logging 2016](https://www.fireeye.com/blog/threat-research/2016/02/greater_visibilityt.html)
#
#
#
# #### Related sigma rules
#
# - [Alternate PowerShell Hosts Pipe](https://github.com/Neo23x0/sigma/blob/master/rules/windows/sysmon/sysmon_alternate_powershell_hosts_pipe.yml)
#
# - [Remote PowerShell Session](https://github.com/Neo23x0/sigma/blob/master/rules/windows/sysmon/sysmon_remote_powershell_session_network.yml)
#
# - [Suspicious Scripting in a WMI Consumer](https://github.com/Neo23x0/sigma/blob/master/rules/windows/sysmon/sysmon_wmi_susp_scripting.yml)
#
# - [PowerShell Execution](https://github.com/Neo23x0/sigma/blob/master/rules/windows/sysmon/sysmon_powershell_execution_moduleload.yml)
#
# - [Alternate PowerShell Hosts Module Load](https://github.com/Neo23x0/sigma/blob/master/rules/windows/sysmon/sysmon_alternate_powershell_hosts_moduleload.yml)
#
# - [PowerShell Rundll32 Remote Thread Creation](https://github.com/Neo23x0/sigma/blob/master/rules/windows/sysmon/sysmon_susp_powershell_rundll32.yml)
#
# - [Malicious PowerShell Commandlet Names](https://github.com/Neo23x0/sigma/blob/master/rules/windows/sysmon/sysmon_powershell_exploit_scripts.yml)
#
# - [PowerShell Network Connections](https://github.com/Neo23x0/sigma/blob/master/rules/windows/sysmon/sysmon_powershell_network_connection.yml)
#
# - [In-memory PowerShell](https://github.com/Neo23x0/sigma/blob/master/rules/windows/sysmon/sysmon_in_memory_powershell.yml)
#
# - [Encoded IEX](https://github.com/Neo23x0/sigma/blob/master/rules/windows/process_creation/win_encoded_iex.yml)
#
# - [APT29](https://github.com/Neo23x0/sigma/blob/master/rules/windows/process_creation/win_apt_apt29_thinktanks.yml)
#
# - [Suspicious Encoded PowerShell Command Line](https://github.com/Neo23x0/sigma/blob/master/rules/windows/process_creation/win_susp_powershell_enc_cmd.yml)
#
# - [Non Interactive PowerShell](https://github.com/Neo23x0/sigma/blob/master/rules/windows/process_creation/win_non_interactive_powershell.yml)
#
# - [Remote PowerShell Session](https://github.com/Neo23x0/sigma/blob/master/rules/windows/process_creation/win_remote_powershell_session_process.yml)
#
# - [Suspicious PowerShell Parameter Substring](https://github.com/Neo23x0/sigma/blob/master/rules/windows/process_creation/win_powershell_suspicious_parameter_variation.yml)
#
# - [Malicious Base64 Encoded PowerShell Keywords in Command Lines](https://github.com/Neo23x0/sigma/blob/master/rules/windows/process_creation/win_susp_powershell_hidden_b64_cmd.yml)
#
# - [Empire Monkey](https://github.com/Neo23x0/sigma/blob/master/rules/windows/process_creation/win_apt_empiremonkey.yml)
#
# - [PowerShell Script Run in AppData](https://github.com/Neo23x0/sigma/blob/master/rules/windows/process_creation/win_susp_ps_appdata.yml)
#
# - [PowerShell Download from URL](https://github.com/Neo23x0/sigma/blob/master/rules/windows/process_creation/win_powershell_download.yml)
#
# - [Powershell AMSI Bypass via .NET Reflection](https://github.com/Neo23x0/sigma/blob/master/rules/windows/process_creation/win_powershell_amsi_bypass.yml)
#
# - [Empire PowerShell Launch Parameters](https://github.com/Neo23x0/sigma/blob/master/rules/windows/process_creation/win_susp_powershell_empire_launch.yml)
#
# - [Baby Shark Activity](https://github.com/Neo23x0/sigma/blob/master/rules/windows/process_creation/win_apt_babyshark.yml)
#
# - [Default PowerSploit and Empire Schtasks Persistence](https://github.com/Neo23x0/sigma/blob/master/rules/windows/process_creation/win_powersploit_empire_schtasks.yml)
#
# - [Encoded FromBase64String](https://github.com/Neo23x0/sigma/blob/master/rules/windows/process_creation/win_encoded_frombase64string.yml)
#
# - [Suspicious XOR Encoded PowerShell Command Line](https://github.com/Neo23x0/sigma/blob/master/rules/windows/process_creation/win_powershell_xor_commandline.yml)
#
# - [Detection of PowerShell Execution via DLL](https://github.com/Neo23x0/sigma/blob/master/rules/windows/process_creation/win_powershell_dll_execution.yml)
#
# - [Suspicious PowerShell Invocation Based on Parent Process](https://github.com/Neo23x0/sigma/blob/master/rules/windows/process_creation/win_susp_powershell_parent_combo.yml)
#
# - [Remote PowerShell Sessions](https://github.com/Neo23x0/sigma/blob/master/rules/windows/builtin/win_remote_powershell_session.yml)
#
# - [Suspicious PowerShell Invocations - Specific](https://github.com/Neo23x0/sigma/blob/master/rules/windows/powershell/powershell_suspicious_invocation_specific.yml)
#
# - [PowerShell Downgrade Attack](https://github.com/Neo23x0/sigma/blob/master/rules/windows/powershell/powershell_downgrade_attack.yml)
#
# - [Malicious PowerShell Keywords](https://github.com/Neo23x0/sigma/blob/master/rules/windows/powershell/powershell_malicious_keywords.yml)
#
# - [PowerShell Credential Prompt](https://github.com/Neo23x0/sigma/blob/master/rules/windows/powershell/powershell_prompt_credentials.yml)
#
# - [PowerShell ShellCode](https://github.com/Neo23x0/sigma/blob/master/rules/windows/powershell/powershell_shellcode_b64.yml)
#
# - [Alternate PowerShell Hosts](https://github.com/Neo23x0/sigma/blob/master/rules/windows/powershell/powershell_alternate_powershell_hosts.yml)
#
# - [Remote PowerShell Session](https://github.com/Neo23x0/sigma/blob/master/rules/windows/powershell/powershell_remote_powershell_session.yml)
#
# - [Suspicious PowerShell Invocations - Generic](https://github.com/Neo23x0/sigma/blob/master/rules/windows/powershell/powershell_suspicious_invocation_generic.yml)
#
# - [Malicious PowerShell Commandlets](https://github.com/Neo23x0/sigma/blob/master/rules/windows/powershell/powershell_malicious_commandlets.yml)
#
# - [PowerShell PSAttack](https://github.com/Neo23x0/sigma/blob/master/rules/windows/powershell/powershell_psattack.yml)
#
# - [Malicious Nishang PowerShell Commandlets](https://github.com/Neo23x0/sigma/blob/master/rules/windows/powershell/powershell_nishang_malicious_commandlets.yml)
#
# - [Suspicious PowerShell Keywords](https://github.com/Neo23x0/sigma/blob/master/rules/windows/powershell/powershell_suspicious_keywords.yml)
#
# - [Suspicious PowerShell Download](https://github.com/Neo23x0/sigma/blob/master/rules/windows/powershell/powershell_suspicious_download.yml)
#
# - [PowerShell Called from an Executable Version Mismatch](https://github.com/Neo23x0/sigma/blob/master/rules/windows/powershell/powershell_exe_calling_ps.yml)
