# %% [markdown]
# ## Goal
#
# ## Categorization
# [Execution/Windows Management Instrumentation](https://attack.mitre.org/techniques/T1047)
#
# ## Strategy Abstract
#
# ## Technical Context
#
# ## Blind Spots and Assumptions
#
# ## False Positives
#
# ## Priority
#
# ## Validation
#
# ## Response
#
# ## Additional Resources
#
#  - [Wikipedia SMB](https://en.wikipedia.org/wiki/Server_Message_Block)
#
#  - [TechNet RPC](https://technet.microsoft.com/en-us/library/cc787851.aspx)
#
#  - [MSDN WMI](https://msdn.microsoft.com/en-us/library/aa394582.aspx)
#
#  - [FireEye WMI 2015](https://www.fireeye.com/content/dam/fireeye-www/global/en/current-threats/pdfs/wp-windows-management-instrumentation.pdf)
#
#
#
# #### Related sigma rules
#
# - [Windows Mangement Instrumentation DLL Loaded Via Microsoft Word](https://github.com/Neo23x0/sigma/blob/master/rules/windows/sysmon/sysmon_susp_winword_wmidll_load.yml)
#
# - [WMI Modules Loaded](https://github.com/Neo23x0/sigma/blob/master/rules/windows/sysmon/sysmon_wmi_module_load.yml)
#
# - [WMI Persistence - Script Event Consumer](https://github.com/Neo23x0/sigma/blob/master/rules/windows/process_creation/win_wmi_persistence_script_event_consumer.yml)
#
# - [Impacket Lateralization Detection](https://github.com/Neo23x0/sigma/blob/master/rules/windows/process_creation/win_impacket_lateralization.yml)
#
# - [SquiblyTwo](https://github.com/Neo23x0/sigma/blob/master/rules/windows/process_creation/win_bypass_squiblytwo.yml)
#
# - [Suspicious WMI Execution](https://github.com/Neo23x0/sigma/blob/master/rules/windows/process_creation/win_susp_wmi_execution.yml)
#
# - [Wmiprvse Spawning Process](https://github.com/Neo23x0/sigma/blob/master/rules/windows/process_creation/win_wmiprvse_spawning_process.yml)
#
# - [Login with WMI](https://github.com/Neo23x0/sigma/blob/master/rules/windows/builtin/win_susp_wmi_login.yml)
#
# - [WMI Persistence](https://github.com/Neo23x0/sigma/blob/master/rules/windows/other/win_wmi_persistence.yml)
