# %% [markdown]
# ## Goal
#
# ## Categorization
# [Execution/Signed Binary Proxy Execution](https://attack.mitre.org/techniques/T1218)
#
# ## Strategy Abstract
#
# ## Technical Context
#
# ## Blind Spots and Assumptions
#
# ## False Positives
#
# ## Priority
#
# ## Validation
#
# ## Response
#
# ## Additional Resources
#
#  - [LOLBAS Msiexec](https://lolbas-project.github.io/lolbas/Binaries/Msiexec/)
#
#  - [Rancor Unit42 June 2018](https://researchcenter.paloaltonetworks.com/2018/06/unit42-rancor-targeted-attacks-south-east-asia-using-plaintee-ddkong-malware-families/)
#
#  - [TrendMicro Msiexec Feb 2018](https://blog.trendmicro.com/trendlabs-security-intelligence/attack-using-windows-installer-msiexec-exe-leads-lokibot/)
#
#  - [Twitter gN3mes1s Status Update MavInject32](https://twitter.com/gn3mes1s/status/941315826107510784)
#
#  - [Twitter monoxgas Status Update SyncAppvPublishingServer](https://twitter.com/monoxgas/status/895045566090010624)
#
#  - [Microsoft odbcconf.exe](https://docs.microsoft.com/en-us/sql/odbc/odbcconf-exe?view=sql-server-2017)
#
#  - [LOLBAS Odbcconf](https://lolbas-project.github.io/lolbas/Binaries/Odbcconf/)
#
#  - [TrendMicro Squiblydoo Aug 2017](https://blog.trendmicro.com/trendlabs-security-intelligence/backdoor-carrying-emails-set-sights-on-russian-speaking-businesses/)
#
#  - [TrendMicro Cobalt Group Nov 2017](https://blog.trendmicro.com/trendlabs-security-intelligence/cobalt-spam-runs-use-macros-cve-2017-8759-exploit/)
#
#  - [GitHub Ultimate AppLocker Bypass List](https://github.com/api0cradle/UltimateAppLockerByPassList)
#
#
#
# #### Related sigma rules
#
# - [Application Whitelisting Bypass via Dnx.exe](https://github.com/Neo23x0/sigma/blob/master/rules/windows/process_creation/win_susp_dnx.yml)
#
# - [Devtoolslauncher.exe Executes Specified Binary](https://github.com/Neo23x0/sigma/blob/master/rules/windows/process_creation/win_susp_devtoolslauncher.yml)
#
# - [Application Whitelisting Bypass via Dxcap.exe](https://github.com/Neo23x0/sigma/blob/master/rules/windows/process_creation/win_susp_dxcap.yml)
#
# - [Application Whitelisting Bypass via DLL Loaded by odbcconf.exe](https://github.com/Neo23x0/sigma/blob/master/rules/windows/process_creation/win_susp_odbcconf.yml)
#
# - [MavInject Process Injection](https://github.com/Neo23x0/sigma/blob/master/rules/windows/process_creation/win_mavinject_proc_inj.yml)
#
# - [Possible App Whitelisting Bypass via WinDbg/CDB as a Shellcode Runner](https://github.com/Neo23x0/sigma/blob/master/rules/windows/process_creation/win_susp_cdb.yml)
#
# - [OpenWith.exe Executes Specified Binary](https://github.com/Neo23x0/sigma/blob/master/rules/windows/process_creation/win_susp_openwith.yml)
#
# - [Curl Start Combination](https://github.com/Neo23x0/sigma/blob/master/rules/windows/process_creation/win_susp_curl_start_combo.yml)
#
# - [Psr.exe Capture Screenshots](https://github.com/Neo23x0/sigma/blob/master/rules/windows/process_creation/win_susp_psr_capture_screenshots.yml)
#
# - [Application Whitelisting Bypass via Bginfo](https://github.com/Neo23x0/sigma/blob/master/rules/windows/process_creation/win_susp_bginfo.yml)
