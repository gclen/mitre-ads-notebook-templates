# %% [markdown]
# ## Goal
#
# ## Categorization
# [Execution/Command-Line Interface](https://attack.mitre.org/techniques/T1059)
#
# ## Strategy Abstract
#
# ## Technical Context
#
# ## Blind Spots and Assumptions
#
# ## False Positives
#
# ## Priority
#
# ## Validation
#
# ## Response
#
# ## Additional Resources
#
#  - [Wikipedia Command-Line Interface](https://en.wikipedia.org/wiki/Command-line_interface)
#
#
#
# #### Related sigma rules
#
# - [Equation Group DLL_U Load](https://github.com/Neo23x0/sigma/blob/master/rules/windows/process_creation/win_apt_equationgroup_dll_u_load.yml)
#
# - [ZxShell Malware](https://github.com/Neo23x0/sigma/blob/master/rules/windows/process_creation/win_apt_zxshell.yml)
#
# - [Suspicious Execution from Outlook](https://github.com/Neo23x0/sigma/blob/master/rules/windows/process_creation/win_susp_outlook.yml)
#
# - [Microsoft Office Product Spawning Windows Shell](https://github.com/Neo23x0/sigma/blob/master/rules/windows/process_creation/win_office_shell.yml)
#
# - [Tasks Folder Evasion](https://github.com/Neo23x0/sigma/blob/master/rules/windows/process_creation/win_task_folder_evasion.yml)
#
# - [Baby Shark Activity](https://github.com/Neo23x0/sigma/blob/master/rules/windows/process_creation/win_apt_babyshark.yml)
#
# - [Fireball Archer Install](https://github.com/Neo23x0/sigma/blob/master/rules/windows/process_creation/win_crime_fireball.yml)
#
# - [MS Office Product Spawning Exe in User Dir](https://github.com/Neo23x0/sigma/blob/master/rules/windows/process_creation/win_office_spawn_exe_from_users_directory.yml)
#
# - [Suspicious HWP Sub Processes](https://github.com/Neo23x0/sigma/blob/master/rules/windows/process_creation/win_hwp_exploits.yml)
#
# - [Command Line Execution with Suspicious URL and AppData Strings](https://github.com/Neo23x0/sigma/blob/master/rules/windows/process_creation/win_susp_cmd_http_appdata.yml)
#
# - [Sofacy Trojan Loader Activity](https://github.com/Neo23x0/sigma/blob/master/rules/windows/process_creation/win_apt_sofacy.yml)
#
# - [Turla Group Lateral Movement](https://github.com/Neo23x0/sigma/blob/master/rules/windows/process_creation/win_apt_turla_commands.yml)
#
# - [Hacktool Ruler](https://github.com/Neo23x0/sigma/blob/master/rules/windows/builtin/win_alert_ruler.yml)
#
# - [Equation Group Indicators](https://github.com/Neo23x0/sigma/blob/master/rules/linux/lnx_apt_equationgroup_lnx.yml)
