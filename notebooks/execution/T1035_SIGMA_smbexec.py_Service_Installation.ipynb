# %% [markdown]
# ## Goal
#
# ## Categorization
# [Execution/Service Execution](https://attack.mitre.org/techniques/T1035)
#
# ## Strategy Abstract
#
# ## Technical Context
#
# ## Blind Spots and Assumptions
#
# ## False Positives
#
# ## Priority
#
# ## Validation
#
# ## Response
#
# ## Additional Resources
#
#
#
# #### Related sigma rules
#
# - [PsExec Service Start](https://github.com/Neo23x0/sigma/blob/master/rules/windows/process_creation/win_psexesvc_start.yml)
#
# - [Service Execution](https://github.com/Neo23x0/sigma/blob/master/rules/windows/process_creation/win_service_execution.yml)
#
# - [smbexec.py Service Installation](https://github.com/Neo23x0/sigma/blob/master/rules/windows/builtin/win_hack_smbexec.yml)
#
# - [Malicious Service Installations](https://github.com/Neo23x0/sigma/blob/master/rules/windows/builtin/win_mal_service_installs.yml)
#
# - [Credential Dumping Tools Service Execution](https://github.com/Neo23x0/sigma/blob/master/rules/windows/builtin/win_mal_creddumper.yml)
#
# - [PsExec Tool Execution](https://github.com/Neo23x0/sigma/blob/master/rules/windows/other/win_tool_psexec.yml)
