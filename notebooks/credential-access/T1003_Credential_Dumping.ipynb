# %% [markdown]
# ## Goal
#
# ## Categorization
# [Credential Access/Credential Dumping](https://attack.mitre.org/techniques/T1003)
#
# ## Strategy Abstract
#
# ## Technical Context
#
# ## Blind Spots and Assumptions
#
# ## False Positives
#
# ## Priority
#
# ## Validation
#
# ## Response
#
# ## Additional Resources
#
#  - [GitHub Creddump7](https://github.com/Neohapsis/creddump7)
#
#  - [Wikipedia Active Directory](https://en.wikipedia.org/wiki/Active_Directory)
#
#  - [Microsoft GPP Key](https://msdn.microsoft.com/library/cc422924.aspx)
#
#  - [SRD GPP](http://blogs.technet.com/b/srd/archive/2014/05/13/ms14-025-an-update-for-group-policy-preferences.aspx)
#
#  - [Obscuresecurity Get-GPPPassword](https://obscuresecurity.blogspot.co.uk/2012/05/gpp-password-retrieval-with-powershell.html)
#
#  - [TechNet Blogs Credential Protection](https://blogs.technet.microsoft.com/askpfeplat/2016/04/18/the-importance-of-kb2871997-and-kb2928120-for-credential-protection/)
#
#  - [Microsoft CredSSP](https://docs.microsoft.com/en-us/previous-versions/windows/it-pro/windows-vista/cc749211(v=ws.10))
#
#  - [Microsoft DRSR Dec 2017](https://msdn.microsoft.com/library/cc228086.aspx)
#
#  - [Microsoft GetNCCChanges](https://msdn.microsoft.com/library/dd207691.aspx)
#
#  - [Samba DRSUAPI](https://wiki.samba.org/index.php/DRSUAPI)
#
#  - [Wine API samlib.dll](https://source.winehq.org/WineAPI/samlib.html)
#
#  - [ADSecurity Mimikatz DCSync](https://adsecurity.org/?p=1729)
#
#  - [Harmj0y Mimikatz and DCSync](http://www.harmj0y.net/blog/redteaming/mimikatz-and-dcsync-and-extrasids-oh-my/)
#
#  - [InsiderThreat ChangeNTLM July 2017](https://blog.stealthbits.com/manipulating-user-passwords-with-mimikatz-SetNTLM-ChangeNTLM)
#
#  - [GitHub Mimikatz lsadump Module](https://github.com/gentilkiwi/mimikatz/wiki/module-~-lsadump)
#
#  - [Microsoft NRPC Dec 2017](https://msdn.microsoft.com/library/cc237008.aspx)
#
#  - [Medium Detecting Attempts to Steal Passwords from Memory](https://medium.com/threatpunter/detecting-attempts-to-steal-passwords-from-memory-558f16dce4ea)
#
#  - [Powersploit](https://github.com/mattifestation/PowerSploit)
#
#  - [Harmj0y DCSync Sept 2015](http://www.harmj0y.net/blog/redteaming/mimikatz-and-dcsync-and-extrasids-oh-my/)
#
#  - [Microsoft SAMR](https://msdn.microsoft.com/library/cc245496.aspx)
#
#  - [AdSecurity DCSync Sept 2015](https://adsecurity.org/?p=1729)
#
#
#
# #### Related sigma rules
#
# - [Password Dumper Remote Thread in LSASS](https://github.com/Neo23x0/sigma/blob/master/rules/windows/sysmon/sysmon_password_dumper_lsass.yml)
#
# - [Mimikatz through Windows Remote Management](https://github.com/Neo23x0/sigma/blob/master/rules/windows/sysmon/sysmon_mimikatz_trough_winrm.yml)
#
# - [LSASS Memory Dump File Creation](https://github.com/Neo23x0/sigma/blob/master/rules/windows/sysmon/sysmon_lsass_memory_dump_file_creation.yml)
#
# - [Detection of SafetyKatz](https://github.com/Neo23x0/sigma/blob/master/rules/windows/sysmon/sysmon_ghostpack_safetykatz.yml)
#
# - [Windows Credential Editor](https://github.com/Neo23x0/sigma/blob/master/rules/windows/sysmon/sysmon_hack_wce.yml)
#
# - [QuarksPwDump Dump File](https://github.com/Neo23x0/sigma/blob/master/rules/windows/sysmon/sysmon_quarkspw_filedump.yml)
#
# - [LSASS Memory Dump](https://github.com/Neo23x0/sigma/blob/master/rules/windows/sysmon/sysmon_lsass_memdump.yml)
#
# - [Mimikatz In-Memory](https://github.com/Neo23x0/sigma/blob/master/rules/windows/sysmon/sysmon_mimikatz_inmemory_detection.yml)
#
# - [Unsigned Image Loaded Into LSASS Process](https://github.com/Neo23x0/sigma/blob/master/rules/windows/sysmon/sysmon_unsigned_image_loaded_into_lsass.yml)
#
# - [Credentials Dumping Tools Accessing LSASS Memory](https://github.com/Neo23x0/sigma/blob/master/rules/windows/sysmon/sysmon_cred_dump_lsass_access.yml)
#
# - [Cred Dump Tools Dropped Files](https://github.com/Neo23x0/sigma/blob/master/rules/windows/sysmon/sysmon_cred_dump_tools_dropped_files.yml)
#
# - [Cred Dump-Tools Named Pipes](https://github.com/Neo23x0/sigma/blob/master/rules/windows/sysmon/sysmon_cred_dump_tools_named_pipes.yml)
#
# - [Dumpert Process Dumper](https://github.com/Neo23x0/sigma/blob/master/rules/windows/sysmon/sysmon_hack_dumpert.yml)
#
# - [Dumping Lsass.exe Memory with MiniDumpWriteDump API](https://github.com/Neo23x0/sigma/blob/master/rules/windows/sysmon/sysmon_minidumwritedump_lsass.yml)
#
# - [Activity Related to NTDS.dit Domain Hash Retrieval](https://github.com/Neo23x0/sigma/blob/master/rules/windows/deprecated/win_susp_vssadmin_ntds_activity.yml)
#
# - [Mimikatz Detection LSASS Access](https://github.com/Neo23x0/sigma/blob/master/rules/windows/deprecated/sysmon_mimikatz_detection_lsass.yml)
#
# - [Copying Sensitive Files with Credential Data](https://github.com/Neo23x0/sigma/blob/master/rules/windows/process_creation/win_copying_sensitive_files_with_credential_data.yml)
#
# - [Suspicious Use of Procdump](https://github.com/Neo23x0/sigma/blob/master/rules/windows/process_creation/win_susp_procdump.yml)
#
# - [SecurityXploded Tool](https://github.com/Neo23x0/sigma/blob/master/rules/windows/process_creation/win_hack_secutyxploded.yml)
#
# - [LSASS Memory Dumping](https://github.com/Neo23x0/sigma/blob/master/rules/windows/process_creation/win_lsass_dump.yml)
#
# - [Process Dump via Comsvcs DLL](https://github.com/Neo23x0/sigma/blob/master/rules/windows/process_creation/win_susp_comsvcs_procdump.yml)
#
# - [Grabbing Sensitive Hives via Reg Utility](https://github.com/Neo23x0/sigma/blob/master/rules/windows/process_creation/win_grabbing_sensitive_hives_via_reg.yml)
#
# - [NotPetya Ransomware Activity](https://github.com/Neo23x0/sigma/blob/master/rules/windows/process_creation/win_malware_notpetya.yml)
#
# - [Shadow Copies Access via Symlink](https://github.com/Neo23x0/sigma/blob/master/rules/windows/process_creation/win_shadow_copies_access_symlink.yml)
#
# - [Mimikatz Command Line](https://github.com/Neo23x0/sigma/blob/master/rules/windows/process_creation/win_mimikatz_command_line.yml)
#
# - [Rubeus Hack Tool](https://github.com/Neo23x0/sigma/blob/master/rules/windows/process_creation/win_hack_rubeus.yml)
#
# - [Judgement Panda Exfil Activity](https://github.com/Neo23x0/sigma/blob/master/rules/windows/process_creation/win_apt_bear_activity_gtr19.yml)
#
# - [Suspicious SYSVOL Domain Group Policy Access](https://github.com/Neo23x0/sigma/blob/master/rules/windows/process_creation/win_susp_sysvol_access.yml)
#
# - [CreateMiniDump Hacktool](https://github.com/Neo23x0/sigma/blob/master/rules/windows/process_creation/win_hktl_createminidump.yml)
#
# - [Invocation of Active Directory Diagnostic Tool (ntdsutil.exe)](https://github.com/Neo23x0/sigma/blob/master/rules/windows/process_creation/win_susp_ntdsutil.yml)
#
# - [Shadow Copies Creation Using Operating Systems Utilities](https://github.com/Neo23x0/sigma/blob/master/rules/windows/process_creation/win_shadow_copies_creation.yml)
#
# - [Cmdkey Cached Credentials Recon](https://github.com/Neo23x0/sigma/blob/master/rules/windows/process_creation/win_cmdkey_recon.yml)
#
# - [Process Dump via Rundll32 and Comsvcs.dll](https://github.com/Neo23x0/sigma/blob/master/rules/windows/process_creation/win_process_dump_rundll32_comsvcs.yml)
#
# - [WCE wceaux.dll Access](https://github.com/Neo23x0/sigma/blob/master/rules/windows/builtin/win_mal_wceaux_dll.yml)
#
# - [DPAPI Domain Master Key Backup Attempt](https://github.com/Neo23x0/sigma/blob/master/rules/windows/builtin/win_dpapi_domain_masterkey_backup_attempt.yml)
#
# - [LSASS Access from Non System Account](https://github.com/Neo23x0/sigma/blob/master/rules/windows/builtin/win_lsass_access_non_system_account.yml)
#
# - [Transfering Files with Credential Data via Network Shares](https://github.com/Neo23x0/sigma/blob/master/rules/windows/builtin/win_transferring_files_with_credential_data_via_network_shares.yml)
#
# - [Malicious Service Installations](https://github.com/Neo23x0/sigma/blob/master/rules/windows/builtin/win_mal_service_installs.yml)
#
# - [QuarksPwDump Clearing Access History](https://github.com/Neo23x0/sigma/blob/master/rules/windows/builtin/win_quarkspwdump_clearing_hive_access_history.yml)
#
# - [LSASS Access Detected via Attack Surface Reduction](https://github.com/Neo23x0/sigma/blob/master/rules/windows/builtin/win_alert_lsass_access.yml)
#
# - [Active Directory Replication from Non Machine Account](https://github.com/Neo23x0/sigma/blob/master/rules/windows/builtin/win_ad_replication_non_machine_account.yml)
#
# - [DPAPI Domain Backup Key Extraction](https://github.com/Neo23x0/sigma/blob/master/rules/windows/builtin/win_dpapi_domain_backupkey_extraction.yml)
#
# - [SAM Dump to AppData](https://github.com/Neo23x0/sigma/blob/master/rules/windows/builtin/win_susp_sam_dump.yml)
#
# - [Possible Impacket SecretDump Remote Activity](https://github.com/Neo23x0/sigma/blob/master/rules/windows/builtin/win_impacket_secretdump.yml)
#
# - [Password Dumper Activity on LSASS](https://github.com/Neo23x0/sigma/blob/master/rules/windows/builtin/win_susp_lsass_dump.yml)
#
# - [Mimikatz Use](https://github.com/Neo23x0/sigma/blob/master/rules/windows/builtin/win_alert_mimikatz_keywords.yml)
#
# - [Generic Password Dumper Activity on LSASS](https://github.com/Neo23x0/sigma/blob/master/rules/windows/builtin/win_susp_lsass_dump_generic.yml)
#
# - [Mimikatz DC Sync](https://github.com/Neo23x0/sigma/blob/master/rules/windows/builtin/win_dcsync.yml)
#
# - [Possible DC Sync](https://github.com/Neo23x0/sigma/blob/master/rules/windows/builtin/win_possible_dc_sync.yml)
#
# - [Credential Dumping Tools Service Execution](https://github.com/Neo23x0/sigma/blob/master/rules/windows/builtin/win_mal_creddumper.yml)
#
# - [Antivirus Password Dumper Detection](https://github.com/Neo23x0/sigma/blob/master/rules/windows/malware/av_password_dumper.yml)
#
# - [Cisco Collect Data](https://github.com/Neo23x0/sigma/blob/master/rules/network/cisco/aaa/cisco_cli_collect_data.yml)
