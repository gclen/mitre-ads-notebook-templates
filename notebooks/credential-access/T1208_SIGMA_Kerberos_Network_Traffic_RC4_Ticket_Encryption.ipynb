# %% [markdown]
# ## Goal
#
# ## Categorization
# [Credential Access/Kerberoasting](https://attack.mitre.org/techniques/T1208)
#
# ## Strategy Abstract
#
# ## Technical Context
#
# ## Blind Spots and Assumptions
#
# ## False Positives
#
# ## Priority
#
# ## Validation
#
# ## Response
#
# ## Additional Resources
#
#  - [Microsoft Detecting Kerberoasting Feb 2018](https://blogs.technet.microsoft.com/motiba/2018/02/23/detecting-kerberoasting-activity-using-azure-security-center/)
#
#  - [Microsoft SPN](https://msdn.microsoft.com/library/ms677949.aspx)
#
#  - [Microsoft SetSPN](https://social.technet.microsoft.com/wiki/contents/articles/717.service-principal-names-spns-setspn-syntax-setspn-exe.aspx)
#
#  - [SANS Attacking Kerberos Nov 2014]()
#
#  - [Harmj0y Kerberoast Nov 2016](https://www.harmj0y.net/blog/powershell/kerberoasting-without-mimikatz/)
#
#  - [Empire InvokeKerberoast Oct 2016](https://github.com/EmpireProject/Empire/blob/master/data/module_source/credentials/Invoke-Kerberoast.ps1)
#
#  - [AdSecurity Cracking Kerberos Dec 2015](https://adsecurity.org/?p=2293)
#
#
#
# #### Related sigma rules
#
# - [Suspicious Outbound Kerberos Connection](https://github.com/Neo23x0/sigma/blob/master/rules/windows/sysmon/sysmon_suspicious_outbound_kerberos_connection.yml)
#
# - [Possible SPN Enumeration](https://github.com/Neo23x0/sigma/blob/master/rules/windows/process_creation/win_spn_enum.yml)
#
# - [User Couldn't Call a Privileged Service 'LsaRegisterLogonProcess'](https://github.com/Neo23x0/sigma/blob/master/rules/windows/builtin/win_user_couldnt_call_privileged_service_lsaregisterlogonprocess.yml)
#
# - [Register new Logon Process by Rubeus](https://github.com/Neo23x0/sigma/blob/master/rules/windows/builtin/win_register_new_logon_process_by_rubeus.yml)
#
# - [Suspicious Outbound Kerberos Connection](https://github.com/Neo23x0/sigma/blob/master/rules/windows/builtin/win_suspicious_outbound_kerberos_connection.yml)
#
# - [Suspicious Kerberos RC4 Ticket Encryption](https://github.com/Neo23x0/sigma/blob/master/rules/windows/builtin/win_susp_rc4_kerberos.yml)
#
# - [Kerberos Network Traffic RC4 Ticket Encryption](https://github.com/Neo23x0/sigma/blob/master/rules/network/zeek_susp_kerberos_rc4.yml)
