# %% [markdown]
# ## Goal
#
# ## Categorization
# [Discovery/Query Registry](https://attack.mitre.org/techniques/T1012)
#
# ## Strategy Abstract
#
# ## Technical Context
#
# ## Blind Spots and Assumptions
#
# ## False Positives
#
# ## Priority
#
# ## Validation
#
# ## Response
#
# ## Additional Resources
#
#  - [capec](https://capec.mitre.org/data/definitions/647.html)
#
#  - [Wikipedia Windows Registry](https://en.wikipedia.org/wiki/Windows_Registry)
#
#
#
# #### Related sigma rules
#
# - [Baby Shark Activity](https://github.com/Neo23x0/sigma/blob/master/rules/windows/process_creation/win_apt_babyshark.yml)
#
# - [Query Registry](https://github.com/Neo23x0/sigma/blob/master/rules/windows/process_creation/win_query_registry.yml)
#
# - [SysKey Registry Keys Access](https://github.com/Neo23x0/sigma/blob/master/rules/windows/builtin/win_syskey_registry_access.yml)
#
# - [SAM Registry Hive Handle Request](https://github.com/Neo23x0/sigma/blob/master/rules/windows/builtin/win_sam_registry_hive_handle_request.yml)
#
# - [Remote Registry Management Using Reg Utility](https://github.com/Neo23x0/sigma/blob/master/rules/windows/builtin/win_remote_registry_management_using_reg_utility.yml)
