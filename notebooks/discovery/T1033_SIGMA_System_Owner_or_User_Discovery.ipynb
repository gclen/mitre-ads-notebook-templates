# %% [markdown]
# ## Goal
#
# ## Categorization
# [Discovery/System Owner/User Discovery](https://attack.mitre.org/techniques/T1033)
#
# ## Strategy Abstract
#
# ## Technical Context
#
# ## Blind Spots and Assumptions
#
# ## False Positives
#
# ## Priority
#
# ## Validation
#
# ## Response
#
# ## Additional Resources
#
#  - [capec](https://capec.mitre.org/data/definitions/577.html)
#
#
#
# #### Related sigma rules
#
# - [Run Whoami as SYSTEM](https://github.com/Neo23x0/sigma/blob/master/rules/windows/process_creation/win_whoami_as_system.yml)
#
# - [Local Accounts Discovery](https://github.com/Neo23x0/sigma/blob/master/rules/windows/process_creation/win_local_system_owner_account_discovery.yml)
#
# - [Whoami Execution](https://github.com/Neo23x0/sigma/blob/master/rules/windows/process_creation/win_susp_whoami.yml)
#
# - [System Owner or User Discovery](https://github.com/Neo23x0/sigma/blob/master/rules/linux/auditd/lnx_auditd_user_discovery.yml)
#
# - [Cisco Discovery](https://github.com/Neo23x0/sigma/blob/master/rules/network/cisco/aaa/cisco_cli_discovery.yml)
