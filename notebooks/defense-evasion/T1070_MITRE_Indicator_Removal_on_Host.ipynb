# %% [markdown]
# ## Goal
#
# ## Categorization
# [Defense Evasion/Indicator Removal on Host](https://attack.mitre.org/techniques/T1070)
#
# ## Strategy Abstract
#
# ## Technical Context
#
# ## Blind Spots and Assumptions
#
# ## False Positives
#
# ## Priority
#
# ## Validation
#
# ## Response
#
# ## Additional Resources
#
#  - [capec](https://capec.mitre.org/data/definitions/93.html)
#
#  - [Microsoft wevtutil Oct 2017](https://docs.microsoft.com/windows-server/administration/windows-commands/wevtutil)
#
#  - [Microsoft EventLog.Clear](https://msdn.microsoft.com/library/system.diagnostics.eventlog.clear.aspx)
#
#  - [Microsoft Clear-EventLog](https://docs.microsoft.com/powershell/module/microsoft.powershell.management/clear-eventlog)
#
#
#
# #### Related sigma rules
#
# - [Possible Ransomware or Unauthorized MBR Modifications](https://github.com/Neo23x0/sigma/blob/master/rules/windows/process_creation/win_susp_bcdedit.yml)
#
# - [Suspicious Eventlog Clear or Configuration Using Wevtutil](https://github.com/Neo23x0/sigma/blob/master/rules/windows/process_creation/win_susp_eventlog_clear.yml)
#
# - [NotPetya Ransomware Activity](https://github.com/Neo23x0/sigma/blob/master/rules/windows/process_creation/win_malware_notpetya.yml)
#
# - [Shadow Copies Deletion Using Operating Systems Utilities](https://github.com/Neo23x0/sigma/blob/master/rules/windows/process_creation/win_shadow_copies_deletion.yml)
#
# - [Fsutil Suspicious Invocation](https://github.com/Neo23x0/sigma/blob/master/rules/windows/process_creation/win_susp_fsutil_usage.yml)
#
# - [Disable of ETW Trace](https://github.com/Neo23x0/sigma/blob/master/rules/windows/process_creation/win_etw_trace_evasion.yml)
#
# - [Eventlog Cleared](https://github.com/Neo23x0/sigma/blob/master/rules/windows/builtin/win_susp_eventlog_cleared.yml)
#
# - [Security Eventlog Cleared](https://github.com/Neo23x0/sigma/blob/master/rules/windows/builtin/win_susp_security_eventlog_cleared.yml)
#
# - [Cisco Clear Logs](https://github.com/Neo23x0/sigma/blob/master/rules/network/cisco/aaa/cisco_cli_clear_logs.yml)
