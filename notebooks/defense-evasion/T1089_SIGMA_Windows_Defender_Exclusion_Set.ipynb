# %% [markdown]
# ## Goal
#
# ## Categorization
# [Defense Evasion/Disabling Security Tools](https://attack.mitre.org/techniques/T1089)
#
# ## Strategy Abstract
#
# ## Technical Context
#
# ## Blind Spots and Assumptions
#
# ## False Positives
#
# ## Priority
#
# ## Validation
#
# ## Response
#
# ## Additional Resources
#
#  - [capec](https://capec.mitre.org/data/definitions/578.html)
#
#
#
# #### Related sigma rules
#
# - [Disable Security Events Logging Adding Reg Key MiniNt](https://github.com/Neo23x0/sigma/blob/master/rules/windows/sysmon/sysmon_disable_security_events_logging_adding_reg_key_minint.yml)
#
# - [Suspect Svchost Memory Asccess](https://github.com/Neo23x0/sigma/blob/master/rules/windows/sysmon/sysmon_invoke_phantom.yml)
#
# - [Weak Encryption Enabled and Kerberoast](https://github.com/Neo23x0/sigma/blob/master/rules/windows/builtin/win_alert_enable_weak_encryption.yml)
#
# - [Microsoft Malware Protection Engine Crash](https://github.com/Neo23x0/sigma/blob/master/rules/windows/builtin/win_susp_msmpeng_crash.yml)
#
# - [Windows Defender Exclusion Set](https://github.com/Neo23x0/sigma/blob/master/rules/windows/other/win_defender_bypass.yml)
#
# - [Cisco Disabling Logging](https://github.com/Neo23x0/sigma/blob/master/rules/network/cisco/aaa/cisco_cli_disable_logging.yml)
#
# - [AWS Config Disabling Channel/Recorder](https://github.com/Neo23x0/sigma/blob/master/rules/cloud/aws_config_disable_recording.yml)
#
# - [AWS CloudTrail Important Change](https://github.com/Neo23x0/sigma/blob/master/rules/cloud/aws_cloudtrail_disable_logging.yml)
#
# - [AWS GuardDuty Important Change](https://github.com/Neo23x0/sigma/blob/master/rules/cloud/aws_guardduty_disruption.yml)
