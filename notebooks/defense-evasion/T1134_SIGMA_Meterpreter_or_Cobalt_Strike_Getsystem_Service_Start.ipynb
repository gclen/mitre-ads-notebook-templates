# %% [markdown]
# ## Goal
#
# ## Categorization
# [Defense Evasion/Access Token Manipulation](https://attack.mitre.org/techniques/T1134)
#
# ## Strategy Abstract
#
# ## Technical Context
#
# ## Blind Spots and Assumptions
#
# ## False Positives
#
# ## Priority
#
# ## Validation
#
# ## Response
#
# ## Additional Resources
#
#  - [capec](https://capec.mitre.org/data/definitions/633.html)
#
#  - [Microsoft runas](https://technet.microsoft.com/en-us/library/bb490994.aspx)
#
#  - [Pentestlab Token Manipulation](https://pentestlab.blog/2017/04/03/token-manipulation/)
#
#  - [BlackHat Atkinson Winchester Token Manipulation](https://www.blackhat.com/docs/eu-17/materials/eu-17-Atkinson-A-Process-Is-No-One-Hunting-For-Token-Manipulation.pdf)
#
#  - [Metasploit access token](https://www.offensive-security.com/metasploit-unleashed/fun-incognito/)
#
#  - [Cobalt Strike Access Token](https://blog.cobaltstrike.com/2015/12/16/windows-access-tokens-and-alternate-credentials/)
#
#  - [Microsoft Command-line Logging](https://technet.microsoft.com/en-us/windows-server-docs/identity/ad-ds/manage/component-updates/command-line-process-auditing)
#
#  - [Microsoft LogonUser](https://msdn.microsoft.com/en-us/library/windows/desktop/aa378184(v=vs.85).aspx)
#
#  - [Microsoft DuplicateTokenEx](https://msdn.microsoft.com/en-us/library/windows/desktop/aa446617(v=vs.85).aspx)
#
#  - [Microsoft ImpersonateLoggedOnUser](https://msdn.microsoft.com/en-us/library/windows/desktop/aa378612(v=vs.85).aspx)
#
#
#
# #### Related sigma rules
#
# - [Detection of Possible Rotten Potato](https://github.com/Neo23x0/sigma/blob/master/rules/windows/process_creation/win_possible_privilege_escalation_using_rotten_potato.yml)
#
# - [Meterpreter or Cobalt Strike Getsystem Service Start](https://github.com/Neo23x0/sigma/blob/master/rules/windows/process_creation/win_meterpreter_or_cobaltstrike_getsystem_service_start.yml)
#
# - [Possible Privilege Escalation via Weak Service Permissions](https://github.com/Neo23x0/sigma/blob/master/rules/windows/process_creation/win_using_sc_to_change_sevice_image_path_by_non_admin.yml)
#
# - [Meterpreter or Cobalt Strike Getsystem Service Installation](https://github.com/Neo23x0/sigma/blob/master/rules/windows/builtin/win_meterpreter_or_cobaltstrike_getsystem_service_installation.yml)
