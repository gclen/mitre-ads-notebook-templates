# %% [markdown]
# ## Goal
#
# ## Categorization
# [Defense Evasion/Obfuscated Files or Information](https://attack.mitre.org/techniques/T1027)
#
# ## Strategy Abstract
#
# ## Technical Context
#
# ## Blind Spots and Assumptions
#
# ## False Positives
#
# ## Priority
#
# ## Validation
#
# ## Response
#
# ## Additional Resources
#
#  - [capec](https://capec.mitre.org/data/definitions/267.html)
#
#  - [Volexity PowerDuke November 2016](https://www.volexity.com/blog/2016/11/09/powerduke-post-election-spear-phishing-campaigns-targeting-think-tanks-and-ngos/)
#
#  - [Linux/Cdorked.A We Live Security Analysis](https://www.welivesecurity.com/2013/04/26/linuxcdorked-new-apache-backdoor-in-the-wild-serves-blackhole/)
#
#  - [Carbon Black Obfuscation Sept 2016](https://www.carbonblack.com/2016/09/23/security-advisory-variants-well-known-adware-families-discovered-include-sophisticated-obfuscation-techniques-previously-associated-nation-state-attacks/)
#
#  - [FireEye Obfuscation June 2017](https://www.fireeye.com/blog/threat-research/2017/06/obfuscation-in-the-wild.html)
#
#  - [FireEye Revoke-Obfuscation July 2017](https://www.fireeye.com/content/dam/fireeye-www/blog/pdfs/revoke-obfuscation-report.pdf)
#
#  - [PaloAlto EncodedCommand March 2017](https://researchcenter.paloaltonetworks.com/2017/03/unit42-pulling-back-the-curtains-on-encodedcommand-powershell-attacks/)
#
#  - [Wikipedia Duqu](https://en.wikipedia.org/wiki/Duqu)
#
#  - [McAfee Malicious Doc Targets Pyeongchang Olympics](https://securingtomorrow.mcafee.com/mcafee-labs/malicious-document-targets-pyeongchang-olympics/)
#
#  - [GitHub Revoke-Obfuscation](https://github.com/danielbohannon/Revoke-Obfuscation)
#
#  - [GitHub Office-Crackros Aug 2016](https://github.com/itsreallynick/office-crackros)
#
#
#
# #### Related sigma rules
#
# - [Executable in ADS](https://github.com/Neo23x0/sigma/blob/master/rules/windows/sysmon/sysmon_ads_executable.yml)
#
# - [FromBase64String Command Line](https://github.com/Neo23x0/sigma/blob/master/rules/windows/process_creation/win_powershell_frombase64string.yml)
#
# - [Net.exe Execution](https://github.com/Neo23x0/sigma/blob/master/rules/windows/process_creation/win_susp_net_execution.yml)
#
# - [Ping Hex IP](https://github.com/Neo23x0/sigma/blob/master/rules/windows/process_creation/win_susp_ping_hex_ip.yml)
#
# - [Invoke-Obfuscation Obfuscated IEX Invocation](https://github.com/Neo23x0/sigma/blob/master/rules/windows/process_creation/win_invoke_obfuscation_obfuscated_iex_commandline.yml)
#
# - [Invoke-Obfuscation Obfuscated IEX Invocation](https://github.com/Neo23x0/sigma/blob/master/rules/windows/builtin/win_invoke_obfuscation_obfuscated_iex_services.yml)
#
# - [Invoke-Obfuscation Obfuscated IEX Invocation](https://github.com/Neo23x0/sigma/blob/master/rules/windows/powershell/powershell_invoke_obfuscation_obfuscated_iex.yml)
