# %% [markdown]
# ## Goal
#
# ## Categorization
# [Defense Evasion/Trusted Developer Utilities](https://attack.mitre.org/techniques/T1127)
#
# ## Strategy Abstract
#
# ## Technical Context
#
# ## Blind Spots and Assumptions
#
# ## False Positives
#
# ## Priority
#
# ## Validation
#
# ## Response
#
# ## Additional Resources
#
#  - [MSDN MSBuild](https://msdn.microsoft.com/library/dd393574.aspx)
#
#  - [LOLBAS Msbuild](https://lolbas-project.github.io/lolbas/Binaries/Msbuild/)
#
#  - [Microsoft Migrating from DNX](https://docs.microsoft.com/en-us/dotnet/core/migration/from-dnx)
#
#  - [engima0x3 DNX Bypass](https://enigma0x3.net/2016/11/17/bypassing-application-whitelisting-by-using-dnx-exe/)
#
#  - [Microsoft Roslyn CPT RCSI](https://blogs.msdn.microsoft.com/visualstudio/2011/10/19/introducing-the-microsoft-roslyn-ctp/)
#
#  - [engima0x3 RCSI Bypass](https://enigma0x3.net/2016/11/21/bypassing-application-whitelisting-by-using-rcsi-exe/)
#
#  - [Microsoft Debugging Tools for Windows](https://docs.microsoft.com/en-us/windows-hardware/drivers/debugger/index)
#
#  - [Exploit Monday WinDbg](http://www.exploit-monday.com/2016/08/windbg-cdb-shellcode-runner.html)
#
#  - [Microsoft Docs File Tracking](https://docs.microsoft.com/visualstudio/msbuild/file-tracking)
#
#  - [LOLBAS Tracker](https://lolbas-project.github.io/lolbas/OtherMSBinaries/Tracker/)
