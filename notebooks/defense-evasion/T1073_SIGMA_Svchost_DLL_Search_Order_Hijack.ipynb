# %% [markdown]
# ## Goal
#
# ## Categorization
# [Defense Evasion/DLL Side-Loading](https://attack.mitre.org/techniques/T1073)
#
# ## Strategy Abstract
#
# ## Technical Context
#
# ## Blind Spots and Assumptions
#
# ## False Positives
#
# ## Priority
#
# ## Validation
#
# ## Response
#
# ## Additional Resources
#
#  - [capec](https://capec.mitre.org/data/definitions/641.html)
#
#  - [MSDN Manifests](https://msdn.microsoft.com/en-us/library/aa375365)
#
#  - [Stewart 2014](https://www.fireeye.com/content/dam/fireeye-www/global/en/current-threats/pdfs/rpt-dll-sideloading.pdf)
#
#
#
# #### Related sigma rules
#
# - [Svchost DLL Search Order Hijack](https://github.com/Neo23x0/sigma/blob/master/rules/windows/sysmon/sysmon_svchost_dll_search_order_hijack.yml)
#
# - [Possible Process Hollowing Image Loading](https://github.com/Neo23x0/sigma/blob/master/rules/windows/sysmon/sysmon_susp_image_load.yml)
#
# - [DHCP Callout DLL Installation](https://github.com/Neo23x0/sigma/blob/master/rules/windows/sysmon/sysmon_dhcp_calloutdll.yml)
#
# - [DNS ServerLevelPluginDll Install](https://github.com/Neo23x0/sigma/blob/master/rules/windows/sysmon/sysmon_dns_serverlevelplugindll.yml)
#
# - [Executable Used by PlugX in Uncommon Location](https://github.com/Neo23x0/sigma/blob/master/rules/windows/process_creation/win_plugx_susp_exe_locations.yml)
#
# - [Suspicious GUP Usage](https://github.com/Neo23x0/sigma/blob/master/rules/windows/process_creation/win_susp_gup.yml)
#
# - [Suspicious Control Panel DLL Load](https://github.com/Neo23x0/sigma/blob/master/rules/windows/process_creation/win_susp_control_dll_load.yml)
#
# - [Winnti Malware HK University Campaign](https://github.com/Neo23x0/sigma/blob/master/rules/windows/process_creation/win_apt_winnti_mal_hk_jan20.yml)
#
# - [DNS Server Error Failed Loading the ServerLevelPluginDLL](https://github.com/Neo23x0/sigma/blob/master/rules/windows/builtin/win_susp_dns_config.yml)
#
# - [DHCP Server Error Failed Loading the CallOut DLL](https://github.com/Neo23x0/sigma/blob/master/rules/windows/builtin/win_susp_dhcp_config_failed.yml)
#
# - [DHCP Server Loaded the CallOut DLL](https://github.com/Neo23x0/sigma/blob/master/rules/windows/builtin/win_susp_dhcp_config.yml)
