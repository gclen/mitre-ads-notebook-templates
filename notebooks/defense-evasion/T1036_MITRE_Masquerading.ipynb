# %% [markdown]
# ## Goal
#
# ## Categorization
# [Defense Evasion/Masquerading](https://attack.mitre.org/techniques/T1036)
#
# ## Strategy Abstract
#
# ## Technical Context
#
# ## Blind Spots and Assumptions
#
# ## False Positives
#
# ## Priority
#
# ## Validation
#
# ## Response
#
# ## Additional Resources
#
#  - [capec](https://capec.mitre.org/data/definitions/177.html)
#
#  - [FireEye APT10 Sept 2018](https://www.fireeye.com/blog/threat-research/2018/09/apt10-targeting-japanese-corporations-using-updated-ttps.html)
#
#  - [Infosecinstitute RTLO Technique](https://resources.infosecinstitute.com/spoof-using-right-to-left-override-rtlo-technique-2/)
#
#  - [Trend Micro PLEAD RTLO](https://blog.trendmicro.com/trendlabs-security-intelligence/plead-targeted-attacks-against-taiwanese-government-agencies-2/)
#
#  - [Kaspersky RTLO Cyber Crime](https://securelist.com/zero-day-vulnerability-in-telegram/83800/)
#
#  - [Threatexpress MetaTwin 2017](https://threatexpress.com/blogs/2017/metatwin-borrowing-microsoft-metadata-and-digital-signatures-to-hide-binaries/)
#
#  - [Endgame Masquerade Ball](https://www.endgame.com/blog/how-hunt-masquerade-ball)
#
#  - [F-Secure CozyDuke](https://www.f-secure.com/documents/996508/1030745/CozyDuke)
#
#  - [Remaiten](https://www.welivesecurity.com/2016/03/30/meet-remaiten-a-linux-bot-on-steroids-targeting-routers-and-potentially-other-iot-devices/)
#
#  - [Fysbis Palo Alto Analysis](https://researchcenter.paloaltonetworks.com/2016/02/a-look-into-fysbis-sofacys-linux-backdoor/)
#
#  - [Fysbis Dr Web Analysis](https://vms.drweb.com/virus/?i=4276269)
#
#  - [Twitter ItsReallyNick Masquerading Update](https://twitter.com/ItsReallyNick/status/1055321652777619457)
#
#
#
# #### Related sigma rules
#
# - [Renamed jusched.exe](https://github.com/Neo23x0/sigma/blob/master/rules/windows/sysmon/sysmon_renamed_jusched.yml)
#
# - [Renamed ProcDump](https://github.com/Neo23x0/sigma/blob/master/rules/windows/sysmon/sysmon_renamed_procdump.yml)
#
# - [Highly Relevant Renamed Binary](https://github.com/Neo23x0/sigma/blob/master/rules/windows/process_creation/win_renamed_binary_highly_relevant.yml)
#
# - [Taskmgr as Parent](https://github.com/Neo23x0/sigma/blob/master/rules/windows/process_creation/win_susp_taskmgr_parent.yml)
#
# - [Windows Processes Suspicious Parent Directory](https://github.com/Neo23x0/sigma/blob/master/rules/windows/process_creation/win_proc_wrong_parent.yml)
#
# - [Suspicious Use of Procdump](https://github.com/Neo23x0/sigma/blob/master/rules/windows/process_creation/win_susp_procdump.yml)
#
# - [Suspicious MsiExec Directory](https://github.com/Neo23x0/sigma/blob/master/rules/windows/process_creation/win_susp_msiexec_cwd.yml)
#
# - [Exploit for CVE-2015-1641](https://github.com/Neo23x0/sigma/blob/master/rules/windows/process_creation/win_exploit_cve_2015_1641.yml)
#
# - [Suspicious Parent of Csc.exe](https://github.com/Neo23x0/sigma/blob/master/rules/windows/process_creation/win_susp_csc.yml)
#
# - [System File Execution Location Anomaly](https://github.com/Neo23x0/sigma/blob/master/rules/windows/process_creation/win_system_exe_anomaly.yml)
#
# - [Suspicious Calculator Usage](https://github.com/Neo23x0/sigma/blob/master/rules/windows/process_creation/win_susp_calc.yml)
#
# - [PowerShell Base64 Encoded Shellcode](https://github.com/Neo23x0/sigma/blob/master/rules/windows/process_creation/win_powershell_b64_shellcode.yml)
#
# - [Suspicious Process Start Locations](https://github.com/Neo23x0/sigma/blob/master/rules/windows/process_creation/win_susp_run_locations.yml)
#
# - [Execution of Renamed PaExec](https://github.com/Neo23x0/sigma/blob/master/rules/windows/process_creation/win_renamed_paexec.yml)
#
# - [Suspicious Program Location Process Starts](https://github.com/Neo23x0/sigma/blob/master/rules/windows/process_creation/win_susp_prog_location_process_starts.yml)
#
# - [Ps.exe Renamed SysInternals Tool](https://github.com/Neo23x0/sigma/blob/master/rules/windows/process_creation/win_apt_ta17_293a_ps.yml)
#
# - [Suspicious Svchost Process](https://github.com/Neo23x0/sigma/blob/master/rules/windows/process_creation/win_susp_svchost.yml)
#
# - [Taskmgr as LOCAL_SYSTEM](https://github.com/Neo23x0/sigma/blob/master/rules/windows/process_creation/win_susp_taskmgr_localsystem.yml)
#
# - [Renamed Binary](https://github.com/Neo23x0/sigma/blob/master/rules/windows/process_creation/win_renamed_binary.yml)
#
# - [Execution in Non-Executable Folder](https://github.com/Neo23x0/sigma/blob/master/rules/windows/process_creation/win_susp_execution_path.yml)
#
# - [Process Dump via Rundll32 and Comsvcs.dll](https://github.com/Neo23x0/sigma/blob/master/rules/windows/process_creation/win_process_dump_rundll32_comsvcs.yml)
#
# - [Executables Started in Suspicious Folder](https://github.com/Neo23x0/sigma/blob/master/rules/windows/process_creation/win_susp_exec_folder.yml)
#
# - [New or Renamed User Account with '$' in Attribute 'SamAccountName'.](https://github.com/Neo23x0/sigma/blob/master/rules/windows/builtin/win_new_or_renamed_user_account_with_dollar_sign.yml)
#
# - [Masquerading as Linux Crond Process](https://github.com/Neo23x0/sigma/blob/master/rules/linux/auditd/lnx_auditd_masquerading_crond.yml)
