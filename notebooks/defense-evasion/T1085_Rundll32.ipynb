# %% [markdown]
# ## Goal
#
# ## Categorization
# [Defense Evasion/Rundll32](https://attack.mitre.org/techniques/T1085)
#
# ## Strategy Abstract
#
# ## Technical Context
#
# ## Blind Spots and Assumptions
#
# ## False Positives
#
# ## Priority
#
# ## Validation
#
# ## Response
#
# ## Additional Resources
#
#  - [Trend Micro CPL](https://www.trendmicro.de/cloud-content/us/pdfs/security-intelligence/white-papers/wp-cpl-malware.pdf)
#
#  - [This is Security Command Line Confusion](https://thisissecurity.stormshield.com/2014/08/20/poweliks-command-line-confusion/)
#
#
#
# #### Related sigma rules
#
# - [Rundll32 Internet Connection](https://github.com/Neo23x0/sigma/blob/master/rules/windows/sysmon/sysmon_rundll32_net_connections.yml)
#
# - [PowerShell Rundll32 Remote Thread Creation](https://github.com/Neo23x0/sigma/blob/master/rules/windows/sysmon/sysmon_susp_powershell_rundll32.yml)
#
# - [Equation Group DLL_U Load](https://github.com/Neo23x0/sigma/blob/master/rules/windows/process_creation/win_apt_equationgroup_dll_u_load.yml)
#
# - [Suspicious Call by Ordinal](https://github.com/Neo23x0/sigma/blob/master/rules/windows/process_creation/win_susp_rundll32_by_ordinal.yml)
#
# - [ZxShell Malware](https://github.com/Neo23x0/sigma/blob/master/rules/windows/process_creation/win_apt_zxshell.yml)
#
# - [TropicTrooper Campaign November 2018](https://github.com/Neo23x0/sigma/blob/master/rules/windows/process_creation/win_apt_tropictrooper.yml)
#
# - [NotPetya Ransomware Activity](https://github.com/Neo23x0/sigma/blob/master/rules/windows/process_creation/win_malware_notpetya.yml)
#
# - [Suspicious Rundll32 Activity](https://github.com/Neo23x0/sigma/blob/master/rules/windows/process_creation/win_susp_rundll32_activity.yml)
#
# - [Unidentified Attacker November 2018](https://github.com/Neo23x0/sigma/blob/master/rules/windows/process_creation/win_apt_unidentified_nov_18.yml)
#
# - [Fireball Archer Install](https://github.com/Neo23x0/sigma/blob/master/rules/windows/process_creation/win_crime_fireball.yml)
#
# - [Suspicious Control Panel DLL Load](https://github.com/Neo23x0/sigma/blob/master/rules/windows/process_creation/win_susp_control_dll_load.yml)
#
# - [Sofacy Trojan Loader Activity](https://github.com/Neo23x0/sigma/blob/master/rules/windows/process_creation/win_apt_sofacy.yml)
