# %% [markdown]
# ## Goal
#
# ## Categorization
# [Defense Evasion/File and Directory Permissions Modification](https://attack.mitre.org/techniques/T1222)
#
# ## Strategy Abstract
#
# ## Technical Context
#
# ## Blind Spots and Assumptions
#
# ## False Positives
#
# ## Priority
#
# ## Validation
#
# ## Response
#
# ## Additional Resources
#
#  - [Microsoft DACL May 2018](https://docs.microsoft.com/windows/desktop/secauthz/dacls-and-aces)
#
#  - [Microsoft File Rights May 2018](https://docs.microsoft.com/windows/desktop/fileio/file-security-and-access-rights)
#
#  - [Unix File Permissions](https://www.tutorialspoint.com/unix/unix-file-permission.htm)
#
#  - [Hybrid Analysis Icacls1 June 2018](https://www.hybrid-analysis.com/sample/ef0d2628823e8e0a0de3b08b8eacaf41cf284c086a948bdfd67f4e4373c14e4d?environmentId=100)
#
#  - [Hybrid Analysis Icacls2 May 2018](https://www.hybrid-analysis.com/sample/22dab012c3e20e3d9291bce14a2bfc448036d3b966c6e78167f4626f5f9e38d6?environmentId=110)
#
#  - [Microsoft icacls OCT 2017](https://docs.microsoft.com/windows-server/administration/windows-commands/icacls)
#
#  - [Microsoft takeown OCT 2017](https://docs.microsoft.com/windows-server/administration/windows-commands/takeown)
#
#  - [Microsoft attrib OCT 2017](https://docs.microsoft.com/windows-server/administration/windows-commands/attrib)
#
#  - [Microsoft SetAcl](https://docs.microsoft.com/powershell/module/microsoft.powershell.security/set-acl)
#
#  - [Linux chmod](https://linux.die.net/man/1/chmod)
#
#  - [Linux chown](https://linux.die.net/man/1/chown)
#
#  - [EventTracker File Permissions Feb 2014](https://www.eventtracker.com/tech-articles/monitoring-file-permission-changes-windows-security-log/)
