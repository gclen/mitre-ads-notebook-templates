# %% [markdown]
# ## Goal
#
# ## Categorization
# [Defense Evasion/Valid Accounts](https://attack.mitre.org/techniques/T1078)
#
# ## Strategy Abstract
#
# ## Technical Context
#
# ## Blind Spots and Assumptions
#
# ## False Positives
#
# ## Priority
#
# ## Validation
#
# ## Response
#
# ## Additional Resources
#
#  - [capec](https://capec.mitre.org/data/definitions/560.html)
#
#  - [Microsoft Local Accounts Feb 2019](https://docs.microsoft.com/en-us/windows/security/identity-protection/access-control/local-accounts)
#
#  - [Metasploit SSH Module](https://github.com/rapid7/metasploit-framework/tree/master/modules/exploits/linux/ssh)
#
#  - [TechNet Credential Theft](https://technet.microsoft.com/en-us/library/dn535501.aspx)
#
#  - [TechNet Audit Policy](https://technet.microsoft.com/en-us/library/dn487457.aspx)
#
#
#
# #### Related sigma rules
#
# - [User Added to Local Administrators](https://github.com/Neo23x0/sigma/blob/master/rules/windows/builtin/win_user_added_to_local_administrators.yml)
#
# - [Failed Logins with Different Accounts from Single Source System](https://github.com/Neo23x0/sigma/blob/master/rules/windows/builtin/win_susp_failed_logons_single_source.yml)
#
# - [Account Tampering - Suspicious Failed Logon Reasons](https://github.com/Neo23x0/sigma/blob/master/rules/windows/builtin/win_susp_failed_logon_reasons.yml)
#
# - [Admin User Remote Logon](https://github.com/Neo23x0/sigma/blob/master/rules/windows/builtin/win_admin_rdp_login.yml)
#
# - [Enabled User Right in AD to Control User Objects](https://github.com/Neo23x0/sigma/blob/master/rules/windows/builtin/win_alert_active_directory_user_control.yml)
#
# - [Interactive Logon to Server Systems](https://github.com/Neo23x0/sigma/blob/master/rules/windows/builtin/win_susp_interactive_logons.yml)
#
# - [AWS Root Credentials](https://github.com/Neo23x0/sigma/blob/master/rules/cloud/aws_root_account_usage.yml)
