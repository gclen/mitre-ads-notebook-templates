# %% [markdown]
# ## Goal
#
# ## Categorization
# [Lateral Movement/Pass the Hash](https://attack.mitre.org/techniques/T1075)
#
# ## Strategy Abstract
#
# ## Technical Context
#
# ## Blind Spots and Assumptions
#
# ## False Positives
#
# ## Priority
#
# ## Validation
#
# ## Response
#
# ## Additional Resources
#
#  - [capec](https://capec.mitre.org/data/definitions/644.html)
#
#  - [NSA Spotting](https://www.iad.gov/iad/library/reports/spotting-the-adversary-with-windows-event-log-monitoring.cfm)
#
#
#
# #### Related sigma rules
#
# - [Successful Overpass the Hash Attempt](https://github.com/Neo23x0/sigma/blob/master/rules/windows/builtin/win_overpass_the_hash.yml)
#
# - [Pass the Hash Activity 2](https://github.com/Neo23x0/sigma/blob/master/rules/windows/builtin/win_pass_the_hash_2.yml)
#
# - [NTLM Logon](https://github.com/Neo23x0/sigma/blob/master/rules/windows/builtin/win_susp_ntlm_auth.yml)
#
# - [Hacktool Ruler](https://github.com/Neo23x0/sigma/blob/master/rules/windows/builtin/win_alert_ruler.yml)
#
# - [Pass the Hash Activity](https://github.com/Neo23x0/sigma/blob/master/rules/windows/builtin/win_pass_the_hash.yml)
