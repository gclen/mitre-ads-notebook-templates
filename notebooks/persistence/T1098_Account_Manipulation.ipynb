# %% [markdown]
# ## Goal
#
# ## Categorization
# [Persistence/Account Manipulation](https://attack.mitre.org/techniques/T1098)
#
# ## Strategy Abstract
#
# ## Technical Context
#
# ## Blind Spots and Assumptions
#
# ## False Positives
#
# ## Priority
#
# ## Validation
#
# ## Response
#
# ## Additional Resources
#
#  - [Microsoft - Add-MailboxPermission](https://docs.microsoft.com/en-us/powershell/module/exchange/mailboxes/add-mailboxpermission?view=exchange-ps)
#
#  - [Bienstock, D. - Defending O365 - 2019](https://www.slideshare.net/DouglasBienstock/shmoocon-2019-becs-and-beyond-investigating-and-defending-office-365)
#
#  - [Blue Cloud of Death](https://speakerdeck.com/tweekfawkes/blue-cloud-of-death-red-teaming-azure-1)
#
#  - [Summit Route Advanced AWS policy auditing](https://summitroute.com/blog/2019/04/03/advanced_aws_policy_auditing_confused_deputies_with_aws_services/)
#
#  - [Microsoft User Modified Event](https://docs.microsoft.com/en-us/windows/security/threat-protection/auditing/event-4738)
#
#  - [InsiderThreat ChangeNTLM July 2017](https://blog.stealthbits.com/manipulating-user-passwords-with-mimikatz-SetNTLM-ChangeNTLM)
#
#  - [GitHub Mimikatz Issue 92 June 2017](https://github.com/gentilkiwi/mimikatz/issues/92)
#
#
#
# #### Related sigma rules
#
# - [Judgement Panda Exfil Activity](https://github.com/Neo23x0/sigma/blob/master/rules/windows/process_creation/win_apt_judgement_panda_gtr19.yml)
#
# - [Active Directory User Backdoors](https://github.com/Neo23x0/sigma/blob/master/rules/windows/builtin/win_alert_ad_user_backdoors.yml)
#
# - [Password Change on Directory Service Restore Mode (DSRM) Account](https://github.com/Neo23x0/sigma/blob/master/rules/windows/builtin/win_susp_dsrm_password_change.yml)
#
# - [Cisco Local Accounts](https://github.com/Neo23x0/sigma/blob/master/rules/network/cisco/aaa/cisco_cli_local_accounts.yml)
#
# - [AWS IAM Backdoor Users Keys](https://github.com/Neo23x0/sigma/blob/master/rules/cloud/aws_iam_backdoor_users_keys.yml)
