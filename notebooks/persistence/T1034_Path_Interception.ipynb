# %% [markdown]
# ## Goal
#
# ## Categorization
# [Persistence/Path Interception](https://attack.mitre.org/techniques/T1034)
#
# ## Strategy Abstract
#
# ## Technical Context
#
# ## Blind Spots and Assumptions
#
# ## False Positives
#
# ## Priority
#
# ## Validation
#
# ## Response
#
# ## Additional Resources
#
#  - [capec](https://capec.mitre.org/data/definitions/159.html)
#
#  - [TechNet MS14-019](https://blogs.technet.microsoft.com/srd/2014/04/08/ms14-019-fixing-a-binary-hijacking-via-cmd-or-bat-file/)
#
#  - [Microsoft Subkey](http://support.microsoft.com/KB/103000)
#
#  - [Baggett 2012](https://isc.sans.edu/diary/Help+eliminate+unquoted+path+vulnerabilities/14464)
#
#  - [SecurityBoulevard Unquoted Services APR 2018](https://securityboulevard.com/2018/04/windows-privilege-escalation-unquoted-services/)
#
#  - [SploitSpren Windows Priv Jan 2018](https://www.sploitspren.com/2018-01-26-Windows-Privilege-Escalation-Guide/)
#
#  - [Microsoft CreateProcess](http://msdn.microsoft.com/en-us/library/ms682425)
#
#  - [Hill NT Shell](http://technet.microsoft.com/en-us/library/cc723564.aspx#XSLTsection127121120120)
#
#  - [Microsoft WinExec](http://msdn.microsoft.com/en-us/library/ms687393)
#
#  - [MSDN Environment Property](https://msdn.microsoft.com/en-us/library/fd7hxfdd.aspx)
