# %% [markdown]
# ## Goal
#
# ## Categorization
# [Persistence/Web Shell](https://attack.mitre.org/techniques/T1100)
#
# ## Strategy Abstract
#
# ## Technical Context
#
# ## Blind Spots and Assumptions
#
# ## False Positives
#
# ## Priority
#
# ## Validation
#
# ## Response
#
# ## Additional Resources
#
#  - [capec](https://capec.mitre.org/data/definitions/650.html)
#
#  - [Lee 2013](https://www.fireeye.com/blog/threat-research/2013/08/breaking-down-the-china-chopper-web-shell-part-i.html)
#
#  - [US-CERT Alert TA15-314A Web Shells](https://www.us-cert.gov/ncas/alerts/TA15-314A)
#
#
#
# #### Related sigma rules
#
# - [Windows Webshell Creation](https://github.com/Neo23x0/sigma/blob/master/rules/windows/sysmon/sysmon_webshell_creation_detect.yml)
#
# - [IIS Native-Code Module Command Line Installation](https://github.com/Neo23x0/sigma/blob/master/rules/windows/process_creation/win_susp_iss_module_install.yml)
#
# - [Shells Spawned by Web Servers](https://github.com/Neo23x0/sigma/blob/master/rules/windows/process_creation/win_webshell_spawn.yml)
#
# - [Webshell Detection With Command Line Keywords](https://github.com/Neo23x0/sigma/blob/master/rules/windows/process_creation/win_webshell_detection.yml)
#
# - [Execution in Webserver Root Folder](https://github.com/Neo23x0/sigma/blob/master/rules/windows/process_creation/win_susp_execution_path_webserver.yml)
#
# - [Antivirus Web Shell Detection](https://github.com/Neo23x0/sigma/blob/master/rules/windows/malware/av_webshell.yml)
#
# - [Oracle WebLogic Exploit](https://github.com/Neo23x0/sigma/blob/master/rules/web/web_cve_2018_2894_weblogic_exploit.yml)
#
# - [Webshell Remote Command Execution](https://github.com/Neo23x0/sigma/blob/master/rules/linux/auditd/lnx_auditd_web_rce.yml)
#
# - [Cisco Modify Configuration](https://github.com/Neo23x0/sigma/blob/master/rules/network/cisco/aaa/cisco_cli_modify_config.yml)
