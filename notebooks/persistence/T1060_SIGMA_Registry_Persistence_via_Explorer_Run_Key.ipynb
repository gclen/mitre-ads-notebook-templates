# %% [markdown]
# ## Goal
#
# ## Categorization
# [Persistence/Registry Run Keys / Startup Folder](https://attack.mitre.org/techniques/T1060)
#
# ## Strategy Abstract
#
# ## Technical Context
#
# ## Blind Spots and Assumptions
#
# ## False Positives
#
# ## Priority
#
# ## Validation
#
# ## Response
#
# ## Additional Resources
#
#  - [capec](https://capec.mitre.org/data/definitions/270.html)
#
#  - [Microsoft Run Key](http://msdn.microsoft.com/en-us/library/aa376977)
#
#  - [Microsoft RunOnceEx APR 2018](https://support.microsoft.com/help/310593/description-of-the-runonceex-registry-key)
#
#  - [Oddvar Moe RunOnceEx Mar 2018](https://oddvar.moe/2018/03/21/persistence-using-runonceex-hidden-from-autoruns-exe/)
#
#  - [TechNet Autoruns](https://technet.microsoft.com/en-us/sysinternals/bb963902)
#
#
#
# #### Related sigma rules
#
# - [Registry Persistence via Explorer Run Key](https://github.com/Neo23x0/sigma/blob/master/rules/windows/sysmon/sysmon_susp_reg_persist_explorer_run.yml)
#
# - [Narrator's Feedback-Hub Persistence](https://github.com/Neo23x0/sigma/blob/master/rules/windows/sysmon/sysmon_narrator_feedback_persistance.yml)
#
# - [New RUN Key Pointing to Suspicious Folder](https://github.com/Neo23x0/sigma/blob/master/rules/windows/sysmon/sysmon_susp_run_key_img_folder.yml)
#
# - [Autorun Keys Modification](https://github.com/Neo23x0/sigma/blob/master/rules/windows/sysmon/sysmon_asep_reg_keys_modification.yml)
#
# - [Suspicious RUN Key from Download](https://github.com/Neo23x0/sigma/blob/master/rules/windows/sysmon/sysmon_susp_download_run_key.yml)
#
# - [Suspicious Netsh DLL Persistence](https://github.com/Neo23x0/sigma/blob/master/rules/windows/process_creation/win_susp_netsh_dll_persistence.yml)
#
# - [Direct Autorun Keys Modification](https://github.com/Neo23x0/sigma/blob/master/rules/windows/process_creation/win_susp_direct_asep_reg_keys_modification.yml)
