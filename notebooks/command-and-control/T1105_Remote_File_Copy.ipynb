# %% [markdown]
# ## Goal
#
# ## Categorization
# [Command And Control/Remote File Copy](https://attack.mitre.org/techniques/T1105)
#
# ## Strategy Abstract
#
# ## Technical Context
#
# ## Blind Spots and Assumptions
#
# ## False Positives
#
# ## Priority
#
# ## Validation
#
# ## Response
#
# ## Additional Resources
#
#  - [University of Birmingham C2](https://arxiv.org/ftp/arxiv/papers/1408/1408.1136.pdf)
#
#
#
# #### Related sigma rules
#
# - [Pandemic Registry Key](https://github.com/Neo23x0/sigma/blob/master/rules/windows/sysmon/sysmon_apt_pandemic.yml)
#
# - [Microsoft Binary Suspicious Communication Endpoint](https://github.com/Neo23x0/sigma/blob/master/rules/windows/sysmon/sysmon_win_binary_susp_com.yml)
#
# - [Microsoft Binary Github Communication](https://github.com/Neo23x0/sigma/blob/master/rules/windows/sysmon/sysmon_win_binary_github_com.yml)
#
# - [Copy from Admin Share](https://github.com/Neo23x0/sigma/blob/master/rules/windows/process_creation/win_susp_copy_lateral_movement.yml)
#
# - [Suspicious Certutil Command](https://github.com/Neo23x0/sigma/blob/master/rules/windows/process_creation/win_susp_certutil_command.yml)
#
# - [Malicious Payload Download via Office Binaries](https://github.com/Neo23x0/sigma/blob/master/rules/windows/process_creation/win_susp_msoffice.yml)
#
# - [Cisco Stage Data](https://github.com/Neo23x0/sigma/blob/master/rules/network/cisco/aaa/cisco_cli_moving_data.yml)
