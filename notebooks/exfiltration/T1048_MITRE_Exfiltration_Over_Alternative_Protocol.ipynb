# %% [markdown]
# ## Goal
#
# ## Categorization
# [Exfiltration/Exfiltration Over Alternative Protocol](https://attack.mitre.org/techniques/T1048)
#
# ## Strategy Abstract
#
# ## Technical Context
#
# ## Blind Spots and Assumptions
#
# ## False Positives
#
# ## Priority
#
# ## Validation
#
# ## Response
#
# ## Additional Resources
#
#  - [Palo Alto OilRig Oct 2016](http://researchcenter.paloaltonetworks.com/2016/10/unit42-oilrig-malware-campaign-updates-toolset-and-expands-targets/)
#
#  - [University of Birmingham C2](https://arxiv.org/ftp/arxiv/papers/1408/1408.1136.pdf)
#
#
#
# #### Related sigma rules
#
# - [Tap Installer Execution](https://github.com/Neo23x0/sigma/blob/master/rules/windows/process_creation/win_tap_installer_execution.yml)
#
# - [DNS Exfiltration Tools Execution](https://github.com/Neo23x0/sigma/blob/master/rules/windows/process_creation/win_dns_exfiltration_tools_execution.yml)
#
# - [Tap Driver Installation](https://github.com/Neo23x0/sigma/blob/master/rules/windows/builtin/win_tap_driver_installation.yml)
#
# - [Dnscat Execution](https://github.com/Neo23x0/sigma/blob/master/rules/windows/powershell/powershell_dnscat_execution.yml)
#
# - [High TXT Records Requests Rate](https://github.com/Neo23x0/sigma/blob/master/rules/network/net_high_txt_records_requests_rate.yml)
#
# - [High DNS Requests Rate](https://github.com/Neo23x0/sigma/blob/master/rules/network/net_high_dns_requests_rate.yml)
#
# - [High NULL Records Requests Rate](https://github.com/Neo23x0/sigma/blob/master/rules/network/net_high_null_records_requests_rate.yml)
#
# - [High DNS Bytes Out](https://github.com/Neo23x0/sigma/blob/master/rules/network/net_high_dns_bytes_out.yml)
#
# - [Possible DNS Tunneling](https://github.com/Neo23x0/sigma/blob/master/rules/network/net_dns_c2_detection.yml)
