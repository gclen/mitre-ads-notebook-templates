# %% [markdown]
# ## Goal
#
# ## Categorization
# [Privilege Escalation/Process Injection](https://attack.mitre.org/techniques/T1055)
#
# ## Strategy Abstract
#
# ## Technical Context
#
# ## Blind Spots and Assumptions
#
# ## False Positives
#
# ## Priority
#
# ## Validation
#
# ## Response
#
# ## Additional Resources
#
#  - [capec](https://capec.mitre.org/data/definitions/640.html)
#
#  - [Endgame Process Injection July 2017](https://www.endgame.com/blog/technical-blog/ten-process-injection-techniques-technical-survey-common-and-trending-process)
#
#  - [Endgame HuntingNMemory June 2017](https://www.endgame.com/blog/technical-blog/hunting-memory)
#
#  - [Microsoft APC](https://msdn.microsoft.com/library/windows/desktop/ms681951.aspx)
#
#  - [CyberBit Early Bird Apr 2018](https://www.cyberbit.com/blog/endpoint-security/new-early-bird-code-injection-technique-discovered/)
#
#  - [ENSIL AtomBombing Oct 2016](https://blog.ensilo.com/atombombing-brand-new-code-injection-for-windows)
#
#  - [Microsoft Atom Table](https://msdn.microsoft.com/library/windows/desktop/ms649053.aspx)
#
#  - [FireEye TLS Nov 2017](https://www.fireeye.com/blog/threat-research/2017/11/ursnif-variant-malicious-tls-callback-technique.html)
#
#  - [Datawire Code Injection](https://www.datawire.io/code-injection-on-linux-and-macos/)
#
#  - [Uninformed Needle](http://hick.org/code/skape/papers/needle.txt)
#
#  - [Phrack halfdead 1997](http://phrack.org/issues/51/8.html)
#
#  - [VDSO hijack 2009](http://vxer.org/lib/vrn00.html)
#
#  - [ArtOfMemoryForensics]()
#
#  - [GNU Acct](https://www.gnu.org/software/acct/)
#
#  - [RHEL auditd](https://access.redhat.com/documentation/red_hat_enterprise_linux/6/html/security_guide/chap-system_auditing)
#
#  - [Chokepoint preload rootkits](http://www.chokepoint.net/2014/02/detecting-userland-preload-rootkits.html)
#
#  - [Microsoft Sysmon v6 May 2017](https://docs.microsoft.com/sysinternals/downloads/sysmon)
#
#  - [Powersploit](https://github.com/mattifestation/PowerSploit)
#
#
#
# #### Related sigma rules
#
# - [CACTUSTORCH Remote Thread Creation](https://github.com/Neo23x0/sigma/blob/master/rules/windows/sysmon/sysmon_cactustorch.yml)
#
# - [CreateRemoteThread API and LoadLibrary](https://github.com/Neo23x0/sigma/blob/master/rules/windows/sysmon/sysmon_createremotethread_loadlibrary.yml)
#
# - [Suspicious Remote Thread Created](https://github.com/Neo23x0/sigma/blob/master/rules/windows/sysmon/sysmon_suspicious_remote_thread.yml)
#
# - [Malware Shellcode in Verclsid Target Process](https://github.com/Neo23x0/sigma/blob/master/rules/windows/sysmon/sysmon_malware_verclsid_shellcode.yml)
#
# - [Suspicious In-Memory Module Execution](https://github.com/Neo23x0/sigma/blob/master/rules/windows/sysmon/sysmon_in_memory_assembly_execution.yml)
#
# - [CobaltStrike Process Injection](https://github.com/Neo23x0/sigma/blob/master/rules/windows/sysmon/sysmon_cobaltstrike_process_injection.yml)
#
# - [Malicious Named Pipe](https://github.com/Neo23x0/sigma/blob/master/rules/windows/sysmon/sysmon_mal_namedpipes.yml)
#
# - [Dridex Process Pattern](https://github.com/Neo23x0/sigma/blob/master/rules/windows/process_creation/win_malware_dridex.yml)
#
# - [Exploit for CVE-2017-0261](https://github.com/Neo23x0/sigma/blob/master/rules/windows/process_creation/win_exploit_cve_2017_0261.yml)
#
# - [Renamed ZOHO Dctask64](https://github.com/Neo23x0/sigma/blob/master/rules/windows/process_creation/win_susp_renamed_dctask64.yml)
#
# - [MavInject Process Injection](https://github.com/Neo23x0/sigma/blob/master/rules/windows/process_creation/win_mavinject_proc_inj.yml)
#
# - [Exploiting SetupComplete.cmd CVE-2019-1378](https://github.com/Neo23x0/sigma/blob/master/rules/windows/process_creation/win_exploit_cve_2019_1378.yml)
#
# - [Suspect Svchost Activity](https://github.com/Neo23x0/sigma/blob/master/rules/windows/process_creation/win_susp_svchost_no_cli.yml)
#
# - [ZOHO Dctask64 Process Injection](https://github.com/Neo23x0/sigma/blob/master/rules/windows/process_creation/win_susp_dctask64_proc_inject.yml)
#
# - [PowerShell ShellCode](https://github.com/Neo23x0/sigma/blob/master/rules/windows/powershell/powershell_shellcode_b64.yml)
#
# - [Modification of ld.so.preload](https://github.com/Neo23x0/sigma/blob/master/rules/linux/auditd/lnx_auditd_ld_so_preload_mod.yml)
