# %% [markdown]
# ## Goal
#
# ## Categorization
# [Privilege Escalation/Accessibility Features](https://attack.mitre.org/techniques/T1015)
#
# ## Strategy Abstract
#
# ## Technical Context
#
# ## Blind Spots and Assumptions
#
# ## False Positives
#
# ## Priority
#
# ## Validation
#
# ## Response
#
# ## Additional Resources
#
#  - [capec](https://capec.mitre.org/data/definitions/558.html)
#
#  - [FireEye Hikit Rootkit](https://www.fireeye.com/blog/threat-research/2012/08/hikit-rootkit-advanced-persistent-attack-techniques-part-1.html)
#
#  - [DEFCON2016 Sticky Keys](https://www.slideshare.net/DennisMaldonado5/sticky-keys-to-the-kingdom)
#
#  - [Tilbury 2014](http://blog.crowdstrike.com/registry-analysis-with-crowdresponse/)
#
#
#
# #### Related sigma rules
#
# - [Sticky Key Like Backdoor Usage](https://github.com/Neo23x0/sigma/blob/master/rules/windows/sysmon/sysmon_stickykey_like_backdoor.yml)
#
# - [Suspicious Debugger Registration Cmdline](https://github.com/Neo23x0/sigma/blob/master/rules/windows/process_creation/win_install_reg_debugger_backdoor.yml)
