# %% [markdown]
# ## Goal
#
# ## Categorization
# [Initial Access/Spearphishing Attachment](https://attack.mitre.org/techniques/T1193)
#
# ## Strategy Abstract
#
# ## Technical Context
#
# ## Blind Spots and Assumptions
#
# ## False Positives
#
# ## Priority
#
# ## Validation
#
# ## Response
#
# ## Additional Resources
#
#  - [capec](https://capec.mitre.org/data/definitions/163.html)
#
#
#
# #### Related sigma rules
#
# - [GAC DLL Loaded Via Office Applications](https://github.com/Neo23x0/sigma/blob/master/rules/windows/sysmon/sysmon_susp_office_dotnet_gac_dll_load.yml)
#
# - [CLR DLL Loaded Via Office Applications](https://github.com/Neo23x0/sigma/blob/master/rules/windows/sysmon/sysmon_susp_office_dotnet_clr_dll_load.yml)
#
# - [Windows Registry Trust Record Modification](https://github.com/Neo23x0/sigma/blob/master/rules/windows/sysmon/sysmon_registry_trust_record_modification.yml)
#
# - [Active Directory Parsing DLL Loaded Via Office Applications](https://github.com/Neo23x0/sigma/blob/master/rules/windows/sysmon/sysmon_susp_office_dsparse_dll_load.yml)
#
# - [dotNET DLL Loaded Via Office Applications](https://github.com/Neo23x0/sigma/blob/master/rules/windows/sysmon/sysmon_susp_office_dotnet_assembly_dll_load.yml)
#
# - [VBA DLL Loaded Via Microsoft Word](https://github.com/Neo23x0/sigma/blob/master/rules/windows/sysmon/sysmon_susp_winword_vbadll_load.yml)
#
# - [Active Directory Kerberos DLL Loaded Via Office Applications](https://github.com/Neo23x0/sigma/blob/master/rules/windows/sysmon/sysmon_susp_office_kerberos_dll_load.yml)
#
# - [Suspicious Double Extension](https://github.com/Neo23x0/sigma/blob/master/rules/windows/process_creation/win_susp_double_extension.yml)
#
# - [Execution in Outlook Temp Folder](https://github.com/Neo23x0/sigma/blob/master/rules/windows/process_creation/win_susp_outlook_temp.yml)
#
# - [Suspicious HWP Sub Processes](https://github.com/Neo23x0/sigma/blob/master/rules/windows/process_creation/win_hwp_exploits.yml)
